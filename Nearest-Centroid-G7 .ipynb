# %% [markdown]
# ## Explication du modèle

# %% [markdown]
# Le modèle Nearest Centroid(centroïde le plus proche) est un algorithme de classification simple qui représente chaque classe par sa moyenne et appartient au domaine de l'apprentissage supervisé.
# Il est l'un des classificateurs les plus sous-utilisés dans le Machine Learning et est quelque peu similaire au modèle K-Nearest Neighbors.
# Son fonctionnement peut être décrit en trois étapes:
# - Le centre de gravité de chaque classe cible est calculé pendant l'entraînement.
# - Après l'entraînement, les distances entre le point X et le centre de gravité de chaque classe sont calculées.
# - Parmi toutes les distances calculées, la distance minimale est choisie.Le centre de gravité auquel la distance du point donné est minimale,sa classe est attribuée au point donné.

# %% [markdown]
# ## Explication des données

# %% [markdown]
# Le jeu de données utilisé est un ensemble d'images sur des variétés de raisins secs Kecimen et Besni.
# Elles sont cultivées en Turquie ont été obtenues par CVS.
# Un total de 900 grains de raisin sec a été utilisé, dont 450 morceaux des deux variétés.
# Ces images ont été soumises à différentes étapes de prétraitement et 7 caractéristiques morphologiques ont été
# extraites.Ces caractéristiques ont été classées à l'aide de trois techniques d'intelligence artificielle différentes.

# %% [markdown]
# Informations sur les attributs :
#
# 1.) Area : Donne le nombre de pixels à l'intérieur des limites du raisin sec.
#
# 2.) Perimeter : Il mesure l'environnement en calculant la distance entre les limites du raisin et les pixels qui l'entourent.
#
# 3.) MajorAxisLength : Donne la longueur de l'axe principal, qui est la plus longue ligne pouvant être tracée sur le raisin sec.
#
# 4.) MinorAxisLength : Donne la longueur du petit axe, qui est la ligne la plus courte pouvant être tracée sur le raisin sec.
#
# 5.) Eccentricity : Donne une mesure de l'excentricité de l'ellipse, qui a les mêmes moments que les raisins secs.
#
# 6.) ConvexArea (Zone convexe) : Donne le nombre de pixels de la plus petite coquille convexe de la région formée par le raisin sec.
#
# 7.) Extent : Indique le rapport entre la région formée par le raisin sec et le nombre total de pixels de la boîte englobante.
#
# 8.) Class : Kecimen et Besni raisin sec.

# %% [markdown]
# ## Implémentation du modèle

# %%
# Importation des modules
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import NearestCentroid
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
# Préparation des données
datas = pd.read_csv('raisin.csv')
datas
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# 2    0.637613   1208.575  Kecimen
# 3    0.699599    844.162  Kecimen
# 4    0.792772   1073.251  Kecimen
# ..        ...        ...      ...
# 895  0.668793   1129.072    Besni
# 896  0.636476   1214.252    Besni
# 897  0.741099   1292.828    Besni
# 898  0.658798   1258.548    Besni
# 899  0.632020   1272.862    Besni
#
# [900 rows x 8 columns]

# %%
# Préprocessing
datas.dtypes
# Out:
# Area                 int64
# MajorAxisLength    float64
# MinorAxisLength    float64
# Eccentricity       float64
# ConvexArea           int64
# Extent             float64
# Perimeter          float64
# Class               object
# dtype: object

# %%
datas['Class'] = datas['Class'].replace(['Besni','Kecimen'],[1,0],regex=True)

# %%
datas.head(700)
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0     87524       442.246011       253.291155      0.819738       90546
# 1     75166       406.690687       243.032436      0.801805       78789
# 2     90856       442.267048       266.328318      0.798354       93717
# 3     45928       286.540559       208.760042      0.684989       47336
# 4     79408       352.190770       290.827533      0.564011       81463
# ..      ...              ...              ...           ...         ...
# 695   86852       456.478688       248.606869      0.838684       90550
# 696   91464       433.219793       273.255461      0.775982       93852
# 697   93441       396.790780       300.812608      0.652122       95370
# 698   94211       450.004617       269.286569      0.801191       96340
# 699  124630       585.093803       275.493613      0.882211      128308
#
#        Extent  Perimeter  Class
# 0    0.758651   1184.040      0
# 1    0.684130   1121.786      0
# 2    0.637613   1208.575      0
# 3    0.699599    844.162      0
# 4    0.792772   1073.251      0
# ..        ...        ...    ...
# 695  0.607854   1207.534      1
# 696  0.717702   1182.210      1
# 697  0.723317   1157.771      1
# 698  0.716848   1194.631      1
# 699  0.681832   1485.990      1
#
# [700 rows x 8 columns]

# %%
# Séparation des données(Train et Test)
Y = datas['Class']
X = datas.drop(['Class'],axis=1)

# %%
X
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter
# 0    0.758651   1184.040
# 1    0.684130   1121.786
# 2    0.637613   1208.575
# 3    0.699599    844.162
# 4    0.792772   1073.251
# ..        ...        ...
# 895  0.668793   1129.072
# 896  0.636476   1214.252
# 897  0.741099   1292.828
# 898  0.658798   1258.548
# 899  0.632020   1272.862
#
# [900 rows x 7 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 895    1
# 896    1
# 897    1
# 898    1
# 899    1
# Name: Class, Length: 900, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=(0.3),random_state=12)

# %%
print('Taille du X:',X.shape,'\nTaille du train:',X_train.shape)
print('Pourcentage train : ',X_train.shape[0]/X.shape[0]*100,'%')
# Out:
# Taille du X: (900, 7)
# Taille du train: (630, 7)
# Pourcentage train :  70.0 %

# %% [markdown]
# ## Comparaison du modèle avec les modèles classiques

# %% [markdown]
# ### Nearest Centroid Classifier

# %%
# Instanciaion du modèle 
model_ncc = NearestCentroid()
# Fitting du modèle
model_ncc.fit(X_train,Y_train)
# Prédiction
pred_ncc = model_ncc.predict(X_test)

# %%
# Paramètres du grid
params = [
    {'metric':['euclidean','manhattan']},
    {'shrink_threshold':[None,0.2,5]}
]
ncc_best_model = GridSearchCV(model_ncc, params, cv=5, verbose=10)
ncc_best_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5; 1/5] START metric=euclidean............................................
# [CV 1/5; 1/5] END .............metric=euclidean;, score=0.833 total time=   0.0s
# [CV 2/5; 1/5] START metric=euclidean............................................
# [CV 2/5; 1/5] END .............metric=euclidean;, score=0.841 total time=   0.0s
# [CV 3/5; 1/5] START metric=euclidean............................................
# [CV 3/5; 1/5] END .............metric=euclidean;, score=0.817 total time=   0.0s
# [CV 4/5; 1/5] START metric=euclidean............................................
# [CV 4/5; 1/5] END .............metric=euclidean;, score=0.786 total time=   0.0s
# [CV 5/5; 1/5] START metric=euclidean............................................
# [CV 5/5; 1/5] END .............metric=euclidean;, score=0.825 total time=   0.0s
# [CV 1/5; 2/5] START metric=manhattan............................................
# [CV 1/5; 2/5] END .............metric=manhattan;, score=0.841 total time=   0.0s
# [CV 2/5; 2/5] START metric=manhattan............................................
# [CV 2/5; 2/5] END .............metric=manhattan;, score=0.849 total time=   0.0s
# [CV 3/5; 2/5] START metric=manhattan............................................
# [CV 3/5; 2/5] END .............metric=manhattan;, score=0.841 total time=   0.0s
# [CV 4/5; 2/5] START metric=manhattan............................................
# [CV 4/5; 2/5] END .............metric=manhattan;, score=0.817 total time=   0.0s
# [CV 5/5; 2/5] START metric=manhattan............................................
# [CV 5/5; 2/5] END .............metric=manhattan;, score=0.833 total time=   0.0s
# [CV 1/5; 3/5] START shrink_threshold=None.......................................
# [CV 1/5; 3/5] END ........shrink_threshold=None;, score=0.833 total time=   0.0s
# [CV 2/5; 3/5] START shrink_threshold=None.......................................
# [CV 2/5; 3/5] END ........shrink_threshold=None;, score=0.841 total time=   0.0s
# [CV 3/5; 3/5] START shrink_threshold=None.......................................
# [CV 3/5; 3/5] END ........shrink_threshold=None;, score=0.817 total time=   0.0s
# [CV 4/5; 3/5] START shrink_threshold=None.......................................
# [CV 4/5; 3/5] END ........shrink_threshold=None;, score=0.786 total time=   0.0s
# [CV 5/5; 3/5] START shrink_threshold=None.......................................
# [CV 5/5; 3/5] END ........shrink_threshold=None;, score=0.825 total time=   0.0s
# [CV 1/5; 4/5] START shrink_threshold=0.2........................................
# [CV 1/5; 4/5] END .........shrink_threshold=0.2;, score=0.833 total time=   0.0s
# [CV 2/5; 4/5] START shrink_threshold=0.2........................................
# [CV 2/5; 4/5] END .........shrink_threshold=0.2;, score=0.841 total time=   0.0s
# [CV 3/5; 4/5] START shrink_threshold=0.2........................................
# [CV 3/5; 4/5] END .........shrink_threshold=0.2;, score=0.817 total time=   0.0s
# [CV 4/5; 4/5] START shrink_threshold=0.2........................................
# [CV 4/5; 4/5] END .........shrink_threshold=0.2;, score=0.786 total time=   0.0s
# [CV 5/5; 4/5] START shrink_threshold=0.2........................................
# [CV 5/5; 4/5] END .........shrink_threshold=0.2;, score=0.825 total time=   0.0s
# [CV 1/5; 5/5] START shrink_threshold=5..........................................
# [CV 1/5; 5/5] END ...........shrink_threshold=5;, score=0.833 total time=   0.0s
# [CV 2/5; 5/5] START shrink_threshold=5..........................................
# [CV 2/5; 5/5] END ...........shrink_threshold=5;, score=0.841 total time=   0.0s
# [CV 3/5; 5/5] START shrink_threshold=5..........................................
# [CV 3/5; 5/5] END ...........shrink_threshold=5;, score=0.817 total time=   0.0s
# [CV 4/5; 5/5] START shrink_threshold=5..........................................
# [CV 4/5; 5/5] END ...........shrink_threshold=5;, score=0.786 total time=   0.0s
# [CV 5/5; 5/5] START shrink_threshold=5..........................................
# [CV 5/5; 5/5] END ...........shrink_threshold=5;, score=0.825 total time=   0.0s
# GridSearchCV(cv=5, estimator=NearestCentroid(),
#              param_grid=[{'metric': ['euclidean', 'manhattan']},
#                          {'shrink_threshold': [None, 0.2, 5]}],
#              verbose=10)

# %%
print('Nearest Centroid Classifier')
# Paramètres optimaux
print('Paramètres optimaux',ncc_best_model.best_params_)
# Modele optimal
print('Modèle optimal',ncc_best_model.best_estimator_)
# Meilleur score
print('Meilleur score',ncc_best_model.best_score_)
# Out:
# Nearest Centroid Classifier
# Paramètres optimaux {'metric': 'manhattan'}
# Modèle optimal NearestCentroid(metric='manhattan')
# Meilleur score 0.8365079365079364

# %% [markdown]
# ### K-Nearest Neighbors

# %%
# Instanciaion du modèle 
model_knn = KNeighborsClassifier()
# Fitting du modèle
model_knn.fit(X_train,Y_train)
# Prédiction
pred_knn = model_knn.predict(X_test)

# %%
# Paramètres du grid
params = [
    {'n_neighbors':[1,8,3,5,7,18,9,4,10,13]},
    {'leaf_size':[2,4,6,8,9,10,5,7]}
]
knn_best_model = GridSearchCV(model_knn, params, cv=5, verbose=10)
knn_best_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START n_neighbors=1..............................................
# [CV 1/5; 1/18] END ...............n_neighbors=1;, score=0.778 total time=   0.0s
# [CV 2/5; 1/18] START n_neighbors=1..............................................
# [CV 2/5; 1/18] END ...............n_neighbors=1;, score=0.849 total time=   0.0s
# [CV 3/5; 1/18] START n_neighbors=1..............................................
# [CV 3/5; 1/18] END ...............n_neighbors=1;, score=0.817 total time=   0.0s
# [CV 4/5; 1/18] START n_neighbors=1..............................................
# [CV 4/5; 1/18] END ...............n_neighbors=1;, score=0.802 total time=   0.0s
# [CV 5/5; 1/18] START n_neighbors=1..............................................
# [CV 5/5; 1/18] END ...............n_neighbors=1;, score=0.786 total time=   0.0s
# [CV 1/5; 2/18] START n_neighbors=8..............................................
# [CV 1/5; 2/18] END ...............n_neighbors=8;, score=0.833 total time=   0.0s
# [CV 2/5; 2/18] START n_neighbors=8..............................................
# [CV 2/5; 2/18] END ...............n_neighbors=8;, score=0.889 total time=   0.0s
# [CV 3/5; 2/18] START n_neighbors=8..............................................
# [CV 3/5; 2/18] END ...............n_neighbors=8;, score=0.849 total time=   0.0s
# [CV 4/5; 2/18] START n_neighbors=8..............................................
# [CV 4/5; 2/18] END ...............n_neighbors=8;, score=0.833 total time=   0.0s
# [CV 5/5; 2/18] START n_neighbors=8..............................................
# [CV 5/5; 2/18] END ...............n_neighbors=8;, score=0.833 total time=   0.0s
# [CV 1/5; 3/18] START n_neighbors=3..............................................
# [CV 1/5; 3/18] END ...............n_neighbors=3;, score=0.833 total time=   0.0s
# [CV 2/5; 3/18] START n_neighbors=3..............................................
# [CV 2/5; 3/18] END ...............n_neighbors=3;, score=0.889 total time=   0.0s
# [CV 3/5; 3/18] START n_neighbors=3..............................................
# [CV 3/5; 3/18] END ...............n_neighbors=3;, score=0.841 total time=   0.0s
# [CV 4/5; 3/18] START n_neighbors=3..............................................
# [CV 4/5; 3/18] END ...............n_neighbors=3;, score=0.794 total time=   0.0s
# [CV 5/5; 3/18] START n_neighbors=3..............................................
# [CV 5/5; 3/18] END ...............n_neighbors=3;, score=0.825 total time=   0.0s
# [CV 1/5; 4/18] START n_neighbors=5..............................................
# [CV 1/5; 4/18] END ...............n_neighbors=5;, score=0.833 total time=   0.0s
# [CV 2/5; 4/18] START n_neighbors=5..............................................
# [CV 2/5; 4/18] END ...............n_neighbors=5;, score=0.873 total time=   0.0s
# [CV 3/5; 4/18] START n_neighbors=5..............................................
# [CV 3/5; 4/18] END ...............n_neighbors=5;, score=0.873 total time=   0.0s
# [CV 4/5; 4/18] START n_neighbors=5..............................................
# [CV 4/5; 4/18] END ...............n_neighbors=5;, score=0.810 total time=   0.0s
# [CV 5/5; 4/18] START n_neighbors=5..............................................
# [CV 5/5; 4/18] END ...............n_neighbors=5;, score=0.857 total time=   0.0s
# [CV 1/5; 5/18] START n_neighbors=7..............................................
# [CV 1/5; 5/18] END ...............n_neighbors=7;, score=0.841 total time=   0.0s
# [CV 2/5; 5/18] START n_neighbors=7..............................................
# [CV 2/5; 5/18] END ...............n_neighbors=7;, score=0.881 total time=   0.0s
# [CV 3/5; 5/18] START n_neighbors=7..............................................
# [CV 3/5; 5/18] END ...............n_neighbors=7;, score=0.865 total time=   0.0s
# [CV 4/5; 5/18] START n_neighbors=7..............................................
# [CV 4/5; 5/18] END ...............n_neighbors=7;, score=0.833 total time=   0.0s
# [CV 5/5; 5/18] START n_neighbors=7..............................................
# [CV 5/5; 5/18] END ...............n_neighbors=7;, score=0.849 total time=   0.0s
# [CV 1/5; 6/18] START n_neighbors=18.............................................
# [CV 1/5; 6/18] END ..............n_neighbors=18;, score=0.857 total time=   0.0s
# [CV 2/5; 6/18] START n_neighbors=18.............................................
# [CV 2/5; 6/18] END ..............n_neighbors=18;, score=0.865 total time=   0.0s
# [CV 3/5; 6/18] START n_neighbors=18.............................................
# [CV 3/5; 6/18] END ..............n_neighbors=18;, score=0.841 total time=   0.0s
# [CV 4/5; 6/18] START n_neighbors=18.............................................
# [CV 4/5; 6/18] END ..............n_neighbors=18;, score=0.817 total time=   0.0s
# [CV 5/5; 6/18] START n_neighbors=18.............................................
# [CV 5/5; 6/18] END ..............n_neighbors=18;, score=0.825 total time=   0.0s
# [CV 1/5; 7/18] START n_neighbors=9..............................................
# [CV 1/5; 7/18] END ...............n_neighbors=9;, score=0.865 total time=   0.0s
# [CV 2/5; 7/18] START n_neighbors=9..............................................
# [CV 2/5; 7/18] END ...............n_neighbors=9;, score=0.881 total time=   0.0s
# [CV 3/5; 7/18] START n_neighbors=9..............................................
# [CV 3/5; 7/18] END ...............n_neighbors=9;, score=0.865 total time=   0.0s
# [CV 4/5; 7/18] START n_neighbors=9..............................................
# [CV 4/5; 7/18] END ...............n_neighbors=9;, score=0.817 total time=   0.0s
# [CV 5/5; 7/18] START n_neighbors=9..............................................
# [CV 5/5; 7/18] END ...............n_neighbors=9;, score=0.833 total time=   0.0s
# [CV 1/5; 8/18] START n_neighbors=4..............................................
# [CV 1/5; 8/18] END ...............n_neighbors=4;, score=0.833 total time=   0.0s
# [CV 2/5; 8/18] START n_neighbors=4..............................................
# [CV 2/5; 8/18] END ...............n_neighbors=4;, score=0.881 total time=   0.0s
# [CV 3/5; 8/18] START n_neighbors=4..............................................
# [CV 3/5; 8/18] END ...............n_neighbors=4;, score=0.857 total time=   0.0s
# [CV 4/5; 8/18] START n_neighbors=4..............................................
# [CV 4/5; 8/18] END ...............n_neighbors=4;, score=0.786 total time=   0.0s
# [CV 5/5; 8/18] START n_neighbors=4..............................................
# [CV 5/5; 8/18] END ...............n_neighbors=4;, score=0.825 total time=   0.0s
# [CV 1/5; 9/18] START n_neighbors=10.............................................
# [CV 1/5; 9/18] END ..............n_neighbors=10;, score=0.833 total time=   0.0s
# [CV 2/5; 9/18] START n_neighbors=10.............................................
# [CV 2/5; 9/18] END ..............n_neighbors=10;, score=0.881 total time=   0.0s
# [CV 3/5; 9/18] START n_neighbors=10.............................................
# [CV 3/5; 9/18] END ..............n_neighbors=10;, score=0.841 total time=   0.0s
# [CV 4/5; 9/18] START n_neighbors=10.............................................
# [CV 4/5; 9/18] END ..............n_neighbors=10;, score=0.817 total time=   0.0s
# [CV 5/5; 9/18] START n_neighbors=10.............................................
# [CV 5/5; 9/18] END ..............n_neighbors=10;, score=0.833 total time=   0.0s
# [CV 1/5; 10/18] START n_neighbors=13............................................
# [CV 1/5; 10/18] END .............n_neighbors=13;, score=0.825 total time=   0.0s
# [CV 2/5; 10/18] START n_neighbors=13............................................
# [CV 2/5; 10/18] END .............n_neighbors=13;, score=0.857 total time=   0.0s
# [CV 3/5; 10/18] START n_neighbors=13............................................
# [CV 3/5; 10/18] END .............n_neighbors=13;, score=0.865 total time=   0.0s
# [CV 4/5; 10/18] START n_neighbors=13............................................
# [CV 4/5; 10/18] END .............n_neighbors=13;, score=0.817 total time=   0.0s
# [CV 5/5; 10/18] START n_neighbors=13............................................
# [CV 5/5; 10/18] END .............n_neighbors=13;, score=0.825 total time=   0.0s
# [CV 1/5; 11/18] START leaf_size=2...............................................
# [CV 1/5; 11/18] END ................leaf_size=2;, score=0.833 total time=   0.0s
# [CV 2/5; 11/18] START leaf_size=2...............................................
# [CV 2/5; 11/18] END ................leaf_size=2;, score=0.873 total time=   0.0s
# [CV 3/5; 11/18] START leaf_size=2...............................................
# [CV 3/5; 11/18] END ................leaf_size=2;, score=0.873 total time=   0.0s
# [CV 4/5; 11/18] START leaf_size=2...............................................
# [CV 4/5; 11/18] END ................leaf_size=2;, score=0.810 total time=   0.0s
# [CV 5/5; 11/18] START leaf_size=2...............................................
# [CV 5/5; 11/18] END ................leaf_size=2;, score=0.857 total time=   0.0s
# [CV 1/5; 12/18] START leaf_size=4...............................................
# [CV 1/5; 12/18] END ................leaf_size=4;, score=0.833 total time=   0.0s
# [CV 2/5; 12/18] START leaf_size=4...............................................
# [CV 2/5; 12/18] END ................leaf_size=4;, score=0.873 total time=   0.0s
# [CV 3/5; 12/18] START leaf_size=4...............................................
# [CV 3/5; 12/18] END ................leaf_size=4;, score=0.873 total time=   0.0s
# [CV 4/5; 12/18] START leaf_size=4...............................................
# [CV 4/5; 12/18] END ................leaf_size=4;, score=0.810 total time=   0.0s
# [CV 5/5; 12/18] START leaf_size=4...............................................
# [CV 5/5; 12/18] END ................leaf_size=4;, score=0.857 total time=   0.0s
# [CV 1/5; 13/18] START leaf_size=6...............................................
# [CV 1/5; 13/18] END ................leaf_size=6;, score=0.833 total time=   0.0s
# [CV 2/5; 13/18] START leaf_size=6...............................................
# [CV 2/5; 13/18] END ................leaf_size=6;, score=0.873 total time=   0.0s
# [CV 3/5; 13/18] START leaf_size=6...............................................
# [CV 3/5; 13/18] END ................leaf_size=6;, score=0.873 total time=   0.0s
# [CV 4/5; 13/18] START leaf_size=6...............................................
# [CV 4/5; 13/18] END ................leaf_size=6;, score=0.810 total time=   0.0s
# [CV 5/5; 13/18] START leaf_size=6...............................................
# [CV 5/5; 13/18] END ................leaf_size=6;, score=0.857 total time=   0.0s
# [CV 1/5; 14/18] START leaf_size=8...............................................
# [CV 1/5; 14/18] END ................leaf_size=8;, score=0.833 total time=   0.0s
# [CV 2/5; 14/18] START leaf_size=8...............................................
# [CV 2/5; 14/18] END ................leaf_size=8;, score=0.873 total time=   0.0s
# [CV 3/5; 14/18] START leaf_size=8...............................................
# [CV 3/5; 14/18] END ................leaf_size=8;, score=0.873 total time=   0.0s
# [CV 4/5; 14/18] START leaf_size=8...............................................
# [CV 4/5; 14/18] END ................leaf_size=8;, score=0.810 total time=   0.0s
# [CV 5/5; 14/18] START leaf_size=8...............................................
# [CV 5/5; 14/18] END ................leaf_size=8;, score=0.857 total time=   0.0s
# [CV 1/5; 15/18] START leaf_size=9...............................................
# [CV 1/5; 15/18] END ................leaf_size=9;, score=0.833 total time=   0.0s
# [CV 2/5; 15/18] START leaf_size=9...............................................
# [CV 2/5; 15/18] END ................leaf_size=9;, score=0.873 total time=   0.0s
# [CV 3/5; 15/18] START leaf_size=9...............................................
# [CV 3/5; 15/18] END ................leaf_size=9;, score=0.873 total time=   0.0s
# [CV 4/5; 15/18] START leaf_size=9...............................................
# [CV 4/5; 15/18] END ................leaf_size=9;, score=0.810 total time=   0.0s
# [CV 5/5; 15/18] START leaf_size=9...............................................
# [CV 5/5; 15/18] END ................leaf_size=9;, score=0.857 total time=   0.0s
# [CV 1/5; 16/18] START leaf_size=10..............................................
# [CV 1/5; 16/18] END ...............leaf_size=10;, score=0.833 total time=   0.0s
# [CV 2/5; 16/18] START leaf_size=10..............................................
# [CV 2/5; 16/18] END ...............leaf_size=10;, score=0.873 total time=   0.0s
# [CV 3/5; 16/18] START leaf_size=10..............................................
# [CV 3/5; 16/18] END ...............leaf_size=10;, score=0.873 total time=   0.0s
# [CV 4/5; 16/18] START leaf_size=10..............................................
# [CV 4/5; 16/18] END ...............leaf_size=10;, score=0.810 total time=   0.0s
# [CV 5/5; 16/18] START leaf_size=10..............................................
# [CV 5/5; 16/18] END ...............leaf_size=10;, score=0.857 total time=   0.0s
# [CV 1/5; 17/18] START leaf_size=5...............................................
# [CV 1/5; 17/18] END ................leaf_size=5;, score=0.833 total time=   0.0s
# [CV 2/5; 17/18] START leaf_size=5...............................................
# [CV 2/5; 17/18] END ................leaf_size=5;, score=0.873 total time=   0.0s
# [CV 3/5; 17/18] START leaf_size=5...............................................
# [CV 3/5; 17/18] END ................leaf_size=5;, score=0.873 total time=   0.0s
# [CV 4/5; 17/18] START leaf_size=5...............................................
# [CV 4/5; 17/18] END ................leaf_size=5;, score=0.810 total time=   0.0s
# [CV 5/5; 17/18] START leaf_size=5...............................................
# [CV 5/5; 17/18] END ................leaf_size=5;, score=0.857 total time=   0.0s
# [CV 1/5; 18/18] START leaf_size=7...............................................
# [CV 1/5; 18/18] END ................leaf_size=7;, score=0.833 total time=   0.0s
# [CV 2/5; 18/18] START leaf_size=7...............................................
# [CV 2/5; 18/18] END ................leaf_size=7;, score=0.873 total time=   0.0s
# [CV 3/5; 18/18] START leaf_size=7...............................................
# [CV 3/5; 18/18] END ................leaf_size=7;, score=0.873 total time=   0.0s
# [CV 4/5; 18/18] START leaf_size=7...............................................
# [CV 4/5; 18/18] END ................leaf_size=7;, score=0.810 total time=   0.0s
# [CV 5/5; 18/18] START leaf_size=7...............................................
# [CV 5/5; 18/18] END ................leaf_size=7;, score=0.857 total time=   0.0s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid=[{'n_neighbors': [1, 8, 3, 5, 7, 18, 9, 4, 10, 13]},
#                          {'leaf_size': [2, 4, 6, 8, 9, 10, 5, 7]}],
#              verbose=10)

# %%
print('K-Nearest Neighbors')
# Paramètres optimaux
print('Paramètres optimaux',knn_best_model.best_params_)
# Modele optimal
print('Modele optimal',knn_best_model.best_estimator_)
# Meilleur score
print('Meilleur score',knn_best_model.best_score_)
# Out:
# K-Nearest Neighbors
# Paramètres optimaux {'n_neighbors': 7}
# Modele optimal KNeighborsClassifier(n_neighbors=7)
# Meilleur score 0.8539682539682539

# %% [markdown]
# ## Logistic Regression

# %%
# Instanciaion du modèle 
model_lr = LogisticRegression()
# Fitting du modèle
model_lr.fit(X_train,Y_train)
# Prédiction
pred_lr = model_lr.predict(X_test)

# %%
#parametre du grid
params=[
    {'penalty':['l1', 'l2', 'elasticnet', 'none']},
    {'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']},
    {'max_iter':[10,34,55,78]}
]
lr_best_model = GridSearchCV(model_lr,params,cv=5,verbose=10)
lr_best_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 13 candidates, totalling 65 fits
# [CV 1/5; 1/13] START penalty=l1.................................................
# [CV 1/5; 1/13] END ....................penalty=l1;, score=nan total time=   0.0s
# [CV 2/5; 1/13] START penalty=l1.................................................
# [CV 2/5; 1/13] END ....................penalty=l1;, score=nan total time=   0.0s
# [CV 3/5; 1/13] START penalty=l1.................................................
# [CV 3/5; 1/13] END ....................penalty=l1;, score=nan total time=   0.0s
# [CV 4/5; 1/13] START penalty=l1.................................................
# [CV 4/5; 1/13] END ....................penalty=l1;, score=nan total time=   0.0s
# [CV 5/5; 1/13] START penalty=l1.................................................
# [CV 5/5; 1/13] END ....................penalty=l1;, score=nan total time=   0.0s
# [CV 1/5; 2/13] START penalty=l2.................................................
# [CV 1/5; 2/13] END ..................penalty=l2;, score=0.865 total time=   0.0s
# [CV 2/5; 2/13] START penalty=l2.................................................
# [CV 2/5; 2/13] END ..................penalty=l2;, score=0.873 total time=   0.0s
# [CV 3/5; 2/13] START penalty=l2.................................................
# [CV 3/5; 2/13] END ..................penalty=l2;, score=0.873 total time=   0.0s
# [CV 4/5; 2/13] START penalty=l2.................................................
# [CV 4/5; 2/13] END ..................penalty=l2;, score=0.833 total time=   0.0s
# [CV 5/5; 2/13] START penalty=l2.................................................
# [CV 5/5; 2/13] END ..................penalty=l2;, score=0.857 total time=   0.0s
# [CV 1/5; 3/13] START penalty=elasticnet.........................................
# [CV 1/5; 3/13] END ............penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5; 3/13] START penalty=elasticnet.........................................
# [CV 2/5; 3/13] END ............penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5; 3/13] START penalty=elasticnet.........................................
# [CV 3/5; 3/13] END ............penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5; 3/13] START penalty=elasticnet.........................................
# [CV 4/5; 3/13] END ............penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5; 3/13] START penalty=elasticnet.........................................
# [CV 5/5; 3/13] END ............penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5; 4/13] START penalty=none...............................................
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 4/13] END ................penalty=none;, score=0.865 total time=   0.0s
# [CV 2/5; 4/13] START penalty=none...............................................
# [CV 2/5; 4/13] END ................penalty=none;, score=0.873 total time=   0.0s
# [CV 3/5; 4/13] START penalty=none...............................................
# [CV 3/5; 4/13] END ................penalty=none;, score=0.881 total time=   0.0s
# [CV 4/5; 4/13] START penalty=none...............................................
# [CV 4/5; 4/13] END ................penalty=none;, score=0.833 total time=   0.0s
# [CV 5/5; 4/13] START penalty=none...............................................
# [CV 5/5; 4/13] END ................penalty=none;, score=0.857 total time=   0.0s
# [CV 1/5; 5/13] START solver=newton-cg...........................................
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# [CV 1/5; 5/13] END ............solver=newton-cg;, score=0.865 total time=   0.2s
# [CV 2/5; 5/13] START solver=newton-cg...........................................
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# [CV 2/5; 5/13] END ............solver=newton-cg;, score=0.873 total time=   0.1s
# [CV 3/5; 5/13] START solver=newton-cg...........................................
# [CV 3/5; 5/13] END ............solver=newton-cg;, score=0.889 total time=   0.1s
# [CV 4/5; 5/13] START solver=newton-cg...........................................
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# [CV 4/5; 5/13] END ............solver=newton-cg;, score=0.833 total time=   0.1s
# [CV 5/5; 5/13] START solver=newton-cg...........................................
# [CV 5/5; 5/13] END ............solver=newton-cg;, score=0.857 total time=   0.1s
# [CV 1/5; 6/13] START solver=lbfgs...............................................
# [CV 1/5; 6/13] END ................solver=lbfgs;, score=0.865 total time=   0.0s
# [CV 2/5; 6/13] START solver=lbfgs...............................................
# [CV 2/5; 6/13] END ................solver=lbfgs;, score=0.873 total time=   0.0s
# [CV 3/5; 6/13] START solver=lbfgs...............................................
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 6/13] END ................solver=lbfgs;, score=0.873 total time=   0.0s
# [CV 4/5; 6/13] START solver=lbfgs...............................................
# [CV 4/5; 6/13] END ................solver=lbfgs;, score=0.833 total time=   0.0s
# [CV 5/5; 6/13] START solver=lbfgs...............................................
# [CV 5/5; 6/13] END ................solver=lbfgs;, score=0.857 total time=   0.0s
# [CV 1/5; 7/13] START solver=liblinear...........................................
# [CV 1/5; 7/13] END ............solver=liblinear;, score=0.873 total time=   0.0s
# [CV 2/5; 7/13] START solver=liblinear...........................................
# [CV 2/5; 7/13] END ............solver=liblinear;, score=0.873 total time=   0.0s
# [CV 3/5; 7/13] START solver=liblinear...........................................
# [CV 3/5; 7/13] END ............solver=liblinear;, score=0.849 total time=   0.0s
# [CV 4/5; 7/13] START solver=liblinear...........................................
# [CV 4/5; 7/13] END ............solver=liblinear;, score=0.833 total time=   0.0s
# [CV 5/5; 7/13] START solver=liblinear...........................................
# [CV 5/5; 7/13] END ............solver=liblinear;, score=0.841 total time=   0.0s
# [CV 1/5; 8/13] START solver=sag.................................................
# [CV 1/5; 8/13] END ..................solver=sag;, score=0.492 total time=   0.0s
# [CV 2/5; 8/13] START solver=sag.................................................
# [CV 2/5; 8/13] END ..................solver=sag;, score=0.492 total time=   0.0s
# [CV 3/5; 8/13] START solver=sag.................................................
# [CV 3/5; 8/13] END ..................solver=sag;, score=0.492 total time=   0.0s
# [CV 4/5; 8/13] START solver=sag.................................................
# [CV 4/5; 8/13] END ..................solver=sag;, score=0.492 total time=   0.0s
# [CV 5/5; 8/13] START solver=sag.................................................
# [CV 5/5; 8/13] END ..................solver=sag;, score=0.492 total time=   0.0s
# [CV 1/5; 9/13] START solver=saga................................................
# [CV 1/5; 9/13] END .................solver=saga;, score=0.492 total time=   0.0s
# [CV 2/5; 9/13] START solver=saga................................................
# [CV 2/5; 9/13] END .................solver=saga;, score=0.492 total time=   0.0s
# [CV 3/5; 9/13] START solver=saga................................................
# [CV 3/5; 9/13] END .................solver=saga;, score=0.492 total time=   0.0s
# [CV 4/5; 9/13] START solver=saga................................................
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 9/13] END .................solver=saga;, score=0.492 total time=   0.0s
# [CV 5/5; 9/13] START solver=saga................................................
# [CV 5/5; 9/13] END .................solver=saga;, score=0.492 total time=   0.0s
# [CV 1/5; 10/13] START max_iter=10...............................................
# [CV 1/5; 10/13] END ................max_iter=10;, score=0.492 total time=   0.0s
# [CV 2/5; 10/13] START max_iter=10...............................................
# [CV 2/5; 10/13] END ................max_iter=10;, score=0.492 total time=   0.0s
# [CV 3/5; 10/13] START max_iter=10...............................................
# [CV 3/5; 10/13] END ................max_iter=10;, score=0.492 total time=   0.0s
# [CV 4/5; 10/13] START max_iter=10...............................................
# [CV 4/5; 10/13] END ................max_iter=10;, score=0.492 total time=   0.0s
# [CV 5/5; 10/13] START max_iter=10...............................................
# [CV 5/5; 10/13] END ................max_iter=10;, score=0.492 total time=   0.0s
# [CV 1/5; 11/13] START max_iter=34...............................................
# [CV 1/5; 11/13] END ................max_iter=34;, score=0.825 total time=   0.0s
# [CV 2/5; 11/13] START max_iter=34...............................................
# [CV 2/5; 11/13] END ................max_iter=34;, score=0.833 total time=   0.0s
# [CV 3/5; 11/13] START max_iter=34...............................................
# [CV 3/5; 11/13] END ................max_iter=34;, score=0.817 total time=   0.0s
# [CV 4/5; 11/13] START max_iter=34...............................................
# [CV 4/5; 11/13] END ................max_iter=34;, score=0.849 total time=   0.0s
# [CV 5/5; 11/13] START max_iter=34...............................................
# [CV 5/5; 11/13] END ................max_iter=34;, score=0.810 total time=   0.0s
# [CV 1/5; 12/13] START max_iter=55...............................................
# [CV 1/5; 12/13] END ................max_iter=55;, score=0.857 total time=   0.0s
# [CV 2/5; 12/13] START max_iter=55...............................................
# [CV 2/5; 12/13] END ................max_iter=55;, score=0.889 total time=   0.0s
# [CV 3/5; 12/13] START max_iter=55...............................................
# [CV 3/5; 12/13] END ................max_iter=55;, score=0.849 total time=   0.0s
# [CV 4/5; 12/13] START max_iter=55...............................................
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 12/13] END ................max_iter=55;, score=0.833 total time=   0.0s
# [CV 5/5; 12/13] START max_iter=55...............................................
# [CV 5/5; 12/13] END ................max_iter=55;, score=0.833 total time=   0.0s
# [CV 1/5; 13/13] START max_iter=78...............................................
# [CV 1/5; 13/13] END ................max_iter=78;, score=0.873 total time=   0.0s
# [CV 2/5; 13/13] START max_iter=78...............................................
# [CV 2/5; 13/13] END ................max_iter=78;, score=0.873 total time=   0.0s
# [CV 3/5; 13/13] START max_iter=78...............................................
# [CV 3/5; 13/13] END ................max_iter=78;, score=0.849 total time=   0.0s
# [CV 4/5; 13/13] START max_iter=78...............................................
# [CV 4/5; 13/13] END ................max_iter=78;, score=0.841 total time=   0.0s
# [CV 5/5; 13/13] START max_iter=78...............................................
# [CV 5/5; 13/13] END ................max_iter=78;, score=0.833 total time=   0.0s
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 65.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.86031746        nan 0.86190476 0.86349206 0.86031746
#  0.85396825 0.49206349 0.49206349 0.49206349 0.82698413 0.85238095
#  0.85396825]
#   warnings.warn(
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid=[{'penalty': ['l1', 'l2', 'elasticnet', 'none']},
#                          {'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']},
#                          {'max_iter': [10, 34, 55, 78]}],
#              verbose=10)

# %%
print('Logistic Regression')
# Paramètres optimaux
print('Paramètres optimaux',lr_best_model.best_params_)
# Modele optimal
print('Modele optimal',lr_best_model.best_estimator_)
# Meilleur score
print('Meilleur score',lr_best_model.best_score_)
# Out:
# Logistic Regression
# Paramètres optimaux {'solver': 'newton-cg'}
# Modele optimal LogisticRegression(solver='newton-cg')
# Meilleur score 0.8634920634920634

# %% [markdown]
# ## Decision Tree Classifier

# %%
# Instanciation
model_dtc = DecisionTreeClassifier()
# Fitting du modéle
model_dtc.fit(X_train, Y_train)
# Prédiction du modéle
pred_dtc = model_dtc.predict(X_test)

# %%
# Paramètres du grid
params=[
    {'criterion':["gini", "entropy"]},
    {'max_depth':[10,15,2,33,5,None]},
    {'min_samples_leaf':[1,5,4,3,2]},
    {'max_leaf_nodes':[None,3,50,100,23,10,56]}
]
dtc_best_model = GridSearchCV(model_dtc,params,cv=5,verbose=10)
dtc_best_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START criterion=gini.............................................
# [CV 1/5; 1/20] END ..............criterion=gini;, score=0.810 total time=   0.0s
# [CV 2/5; 1/20] START criterion=gini.............................................
# [CV 2/5; 1/20] END ..............criterion=gini;, score=0.833 total time=   0.0s
# [CV 3/5; 1/20] START criterion=gini.............................................
# [CV 3/5; 1/20] END ..............criterion=gini;, score=0.825 total time=   0.0s
# [CV 4/5; 1/20] START criterion=gini.............................................
# [CV 4/5; 1/20] END ..............criterion=gini;, score=0.833 total time=   0.0s
# [CV 5/5; 1/20] START criterion=gini.............................................
# [CV 5/5; 1/20] END ..............criterion=gini;, score=0.841 total time=   0.0s
# [CV 1/5; 2/20] START criterion=entropy..........................................
# [CV 1/5; 2/20] END ...........criterion=entropy;, score=0.746 total time=   0.0s
# [CV 2/5; 2/20] START criterion=entropy..........................................
# [CV 2/5; 2/20] END ...........criterion=entropy;, score=0.762 total time=   0.0s
# [CV 3/5; 2/20] START criterion=entropy..........................................
# [CV 3/5; 2/20] END ...........criterion=entropy;, score=0.857 total time=   0.0s
# [CV 4/5; 2/20] START criterion=entropy..........................................
# [CV 4/5; 2/20] END ...........criterion=entropy;, score=0.770 total time=   0.0s
# [CV 5/5; 2/20] START criterion=entropy..........................................
# [CV 5/5; 2/20] END ...........criterion=entropy;, score=0.817 total time=   0.0s
# [CV 1/5; 3/20] START max_depth=10...............................................
# [CV 1/5; 3/20] END ................max_depth=10;, score=0.794 total time=   0.0s
# [CV 2/5; 3/20] START max_depth=10...............................................
# [CV 2/5; 3/20] END ................max_depth=10;, score=0.857 total time=   0.0s
# [CV 3/5; 3/20] START max_depth=10...............................................
# [CV 3/5; 3/20] END ................max_depth=10;, score=0.841 total time=   0.0s
# [CV 4/5; 3/20] START max_depth=10...............................................
# [CV 4/5; 3/20] END ................max_depth=10;, score=0.810 total time=   0.0s
# [CV 5/5; 3/20] START max_depth=10...............................................
# [CV 5/5; 3/20] END ................max_depth=10;, score=0.849 total time=   0.0s
# [CV 1/5; 4/20] START max_depth=15...............................................
# [CV 1/5; 4/20] END ................max_depth=15;, score=0.802 total time=   0.0s
# [CV 2/5; 4/20] START max_depth=15...............................................
# [CV 2/5; 4/20] END ................max_depth=15;, score=0.865 total time=   0.0s
# [CV 3/5; 4/20] START max_depth=15...............................................
# [CV 3/5; 4/20] END ................max_depth=15;, score=0.833 total time=   0.0s
# [CV 4/5; 4/20] START max_depth=15...............................................
# [CV 4/5; 4/20] END ................max_depth=15;, score=0.817 total time=   0.0s
# [CV 5/5; 4/20] START max_depth=15...............................................
# [CV 5/5; 4/20] END ................max_depth=15;, score=0.849 total time=   0.0s
# [CV 1/5; 5/20] START max_depth=2................................................
# [CV 1/5; 5/20] END .................max_depth=2;, score=0.857 total time=   0.0s
# [CV 2/5; 5/20] START max_depth=2................................................
# [CV 2/5; 5/20] END .................max_depth=2;, score=0.889 total time=   0.0s
# [CV 3/5; 5/20] START max_depth=2................................................
# [CV 3/5; 5/20] END .................max_depth=2;, score=0.905 total time=   0.0s
# [CV 4/5; 5/20] START max_depth=2................................................
# [CV 4/5; 5/20] END .................max_depth=2;, score=0.841 total time=   0.0s
# [CV 5/5; 5/20] START max_depth=2................................................
# [CV 5/5; 5/20] END .................max_depth=2;, score=0.865 total time=   0.0s
# [CV 1/5; 6/20] START max_depth=33...............................................
# [CV 1/5; 6/20] END ................max_depth=33;, score=0.802 total time=   0.0s
# [CV 2/5; 6/20] START max_depth=33...............................................
# [CV 2/5; 6/20] END ................max_depth=33;, score=0.849 total time=   0.0s
# [CV 3/5; 6/20] START max_depth=33...............................................
# [CV 3/5; 6/20] END ................max_depth=33;, score=0.833 total time=   0.0s
# [CV 4/5; 6/20] START max_depth=33...............................................
# [CV 4/5; 6/20] END ................max_depth=33;, score=0.841 total time=   0.0s
# [CV 5/5; 6/20] START max_depth=33...............................................
# [CV 5/5; 6/20] END ................max_depth=33;, score=0.873 total time=   0.0s
# [CV 1/5; 7/20] START max_depth=5................................................
# [CV 1/5; 7/20] END .................max_depth=5;, score=0.849 total time=   0.0s
# [CV 2/5; 7/20] START max_depth=5................................................
# [CV 2/5; 7/20] END .................max_depth=5;, score=0.865 total time=   0.0s
# [CV 3/5; 7/20] START max_depth=5................................................
# [CV 3/5; 7/20] END .................max_depth=5;, score=0.873 total time=   0.0s
# [CV 4/5; 7/20] START max_depth=5................................................
# [CV 4/5; 7/20] END .................max_depth=5;, score=0.810 total time=   0.0s
# [CV 5/5; 7/20] START max_depth=5................................................
# [CV 5/5; 7/20] END .................max_depth=5;, score=0.873 total time=   0.0s
# [CV 1/5; 8/20] START max_depth=None.............................................
# [CV 1/5; 8/20] END ..............max_depth=None;, score=0.817 total time=   0.0s
# [CV 2/5; 8/20] START max_depth=None.............................................
# [CV 2/5; 8/20] END ..............max_depth=None;, score=0.865 total time=   0.0s
# [CV 3/5; 8/20] START max_depth=None.............................................
# [CV 3/5; 8/20] END ..............max_depth=None;, score=0.833 total time=   0.0s
# [CV 4/5; 8/20] START max_depth=None.............................................
# [CV 4/5; 8/20] END ..............max_depth=None;, score=0.833 total time=   0.0s
# [CV 5/5; 8/20] START max_depth=None.............................................
# [CV 5/5; 8/20] END ..............max_depth=None;, score=0.865 total time=   0.0s
# [CV 1/5; 9/20] START min_samples_leaf=1.........................................
# [CV 1/5; 9/20] END ..........min_samples_leaf=1;, score=0.802 total time=   0.0s
# [CV 2/5; 9/20] START min_samples_leaf=1.........................................
# [CV 2/5; 9/20] END ..........min_samples_leaf=1;, score=0.857 total time=   0.0s
# [CV 3/5; 9/20] START min_samples_leaf=1.........................................
# [CV 3/5; 9/20] END ..........min_samples_leaf=1;, score=0.825 total time=   0.0s
# [CV 4/5; 9/20] START min_samples_leaf=1.........................................
# [CV 4/5; 9/20] END ..........min_samples_leaf=1;, score=0.833 total time=   0.0s
# [CV 5/5; 9/20] START min_samples_leaf=1.........................................
# [CV 5/5; 9/20] END ..........min_samples_leaf=1;, score=0.857 total time=   0.0s
# [CV 1/5; 10/20] START min_samples_leaf=5........................................
# [CV 1/5; 10/20] END .........min_samples_leaf=5;, score=0.857 total time=   0.0s
# [CV 2/5; 10/20] START min_samples_leaf=5........................................
# [CV 2/5; 10/20] END .........min_samples_leaf=5;, score=0.849 total time=   0.0s
# [CV 3/5; 10/20] START min_samples_leaf=5........................................
# [CV 3/5; 10/20] END .........min_samples_leaf=5;, score=0.849 total time=   0.0s
# [CV 4/5; 10/20] START min_samples_leaf=5........................................
# [CV 4/5; 10/20] END .........min_samples_leaf=5;, score=0.778 total time=   0.0s
# [CV 5/5; 10/20] START min_samples_leaf=5........................................
# [CV 5/5; 10/20] END .........min_samples_leaf=5;, score=0.881 total time=   0.0s
# [CV 1/5; 11/20] START min_samples_leaf=4........................................
# [CV 1/5; 11/20] END .........min_samples_leaf=4;, score=0.841 total time=   0.0s
# [CV 2/5; 11/20] START min_samples_leaf=4........................................
# [CV 2/5; 11/20] END .........min_samples_leaf=4;, score=0.849 total time=   0.0s
# [CV 3/5; 11/20] START min_samples_leaf=4........................................
# [CV 3/5; 11/20] END .........min_samples_leaf=4;, score=0.817 total time=   0.0s
# [CV 4/5; 11/20] START min_samples_leaf=4........................................
# [CV 4/5; 11/20] END .........min_samples_leaf=4;, score=0.762 total time=   0.0s
# [CV 5/5; 11/20] START min_samples_leaf=4........................................
# [CV 5/5; 11/20] END .........min_samples_leaf=4;, score=0.889 total time=   0.0s
# [CV 1/5; 12/20] START min_samples_leaf=3........................................
# [CV 1/5; 12/20] END .........min_samples_leaf=3;, score=0.825 total time=   0.0s
# [CV 2/5; 12/20] START min_samples_leaf=3........................................
# [CV 2/5; 12/20] END .........min_samples_leaf=3;, score=0.857 total time=   0.0s
# [CV 3/5; 12/20] START min_samples_leaf=3........................................
# [CV 3/5; 12/20] END .........min_samples_leaf=3;, score=0.825 total time=   0.0s
# [CV 4/5; 12/20] START min_samples_leaf=3........................................
# [CV 4/5; 12/20] END .........min_samples_leaf=3;, score=0.778 total time=   0.0s
# [CV 5/5; 12/20] START min_samples_leaf=3........................................
# [CV 5/5; 12/20] END .........min_samples_leaf=3;, score=0.881 total time=   0.0s
# [CV 1/5; 13/20] START min_samples_leaf=2........................................
# [CV 1/5; 13/20] END .........min_samples_leaf=2;, score=0.833 total time=   0.0s
# [CV 2/5; 13/20] START min_samples_leaf=2........................................
# [CV 2/5; 13/20] END .........min_samples_leaf=2;, score=0.857 total time=   0.0s
# [CV 3/5; 13/20] START min_samples_leaf=2........................................
# [CV 3/5; 13/20] END .........min_samples_leaf=2;, score=0.849 total time=   0.0s
# [CV 4/5; 13/20] START min_samples_leaf=2........................................
# [CV 4/5; 13/20] END .........min_samples_leaf=2;, score=0.794 total time=   0.0s
# [CV 5/5; 13/20] START min_samples_leaf=2........................................
# [CV 5/5; 13/20] END .........min_samples_leaf=2;, score=0.857 total time=   0.0s
# [CV 1/5; 14/20] START max_leaf_nodes=None.......................................
# [CV 1/5; 14/20] END ........max_leaf_nodes=None;, score=0.817 total time=   0.0s
# [CV 2/5; 14/20] START max_leaf_nodes=None.......................................
# [CV 2/5; 14/20] END ........max_leaf_nodes=None;, score=0.849 total time=   0.0s
# [CV 3/5; 14/20] START max_leaf_nodes=None.......................................
# [CV 3/5; 14/20] END ........max_leaf_nodes=None;, score=0.810 total time=   0.0s
# [CV 4/5; 14/20] START max_leaf_nodes=None.......................................
# [CV 4/5; 14/20] END ........max_leaf_nodes=None;, score=0.825 total time=   0.0s
# [CV 5/5; 14/20] START max_leaf_nodes=None.......................................
# [CV 5/5; 14/20] END ........max_leaf_nodes=None;, score=0.857 total time=   0.0s
# [CV 1/5; 15/20] START max_leaf_nodes=3..........................................
# [CV 1/5; 15/20] END ...........max_leaf_nodes=3;, score=0.857 total time=   0.0s
# [CV 2/5; 15/20] START max_leaf_nodes=3..........................................
# [CV 2/5; 15/20] END ...........max_leaf_nodes=3;, score=0.889 total time=   0.0s
# [CV 3/5; 15/20] START max_leaf_nodes=3..........................................
# [CV 3/5; 15/20] END ...........max_leaf_nodes=3;, score=0.905 total time=   0.0s
# [CV 4/5; 15/20] START max_leaf_nodes=3..........................................
# [CV 4/5; 15/20] END ...........max_leaf_nodes=3;, score=0.841 total time=   0.0s
# [CV 5/5; 15/20] START max_leaf_nodes=3..........................................
# [CV 5/5; 15/20] END ...........max_leaf_nodes=3;, score=0.865 total time=   0.0s
# [CV 1/5; 16/20] START max_leaf_nodes=50.........................................
# [CV 1/5; 16/20] END ..........max_leaf_nodes=50;, score=0.794 total time=   0.0s
# [CV 2/5; 16/20] START max_leaf_nodes=50.........................................
# [CV 2/5; 16/20] END ..........max_leaf_nodes=50;, score=0.849 total time=   0.0s
# [CV 3/5; 16/20] START max_leaf_nodes=50.........................................
# [CV 3/5; 16/20] END ..........max_leaf_nodes=50;, score=0.833 total time=   0.0s
# [CV 4/5; 16/20] START max_leaf_nodes=50.........................................
# [CV 4/5; 16/20] END ..........max_leaf_nodes=50;, score=0.849 total time=   0.0s
# [CV 5/5; 16/20] START max_leaf_nodes=50.........................................
# [CV 5/5; 16/20] END ..........max_leaf_nodes=50;, score=0.857 total time=   0.0s
# [CV 1/5; 17/20] START max_leaf_nodes=100........................................
# [CV 1/5; 17/20] END .........max_leaf_nodes=100;, score=0.802 total time=   0.0s
# [CV 2/5; 17/20] START max_leaf_nodes=100........................................
# [CV 2/5; 17/20] END .........max_leaf_nodes=100;, score=0.849 total time=   0.0s
# [CV 3/5; 17/20] START max_leaf_nodes=100........................................
# [CV 3/5; 17/20] END .........max_leaf_nodes=100;, score=0.825 total time=   0.0s
# [CV 4/5; 17/20] START max_leaf_nodes=100........................................
# [CV 4/5; 17/20] END .........max_leaf_nodes=100;, score=0.833 total time=   0.0s
# [CV 5/5; 17/20] START max_leaf_nodes=100........................................
# [CV 5/5; 17/20] END .........max_leaf_nodes=100;, score=0.833 total time=   0.0s
# [CV 1/5; 18/20] START max_leaf_nodes=23.........................................
# [CV 1/5; 18/20] END ..........max_leaf_nodes=23;, score=0.849 total time=   0.0s
# [CV 2/5; 18/20] START max_leaf_nodes=23.........................................
# [CV 2/5; 18/20] END ..........max_leaf_nodes=23;, score=0.865 total time=   0.0s
# [CV 3/5; 18/20] START max_leaf_nodes=23.........................................
# [CV 3/5; 18/20] END ..........max_leaf_nodes=23;, score=0.889 total time=   0.0s
# [CV 4/5; 18/20] START max_leaf_nodes=23.........................................
# [CV 4/5; 18/20] END ..........max_leaf_nodes=23;, score=0.802 total time=   0.0s
# [CV 5/5; 18/20] START max_leaf_nodes=23.........................................
# [CV 5/5; 18/20] END ..........max_leaf_nodes=23;, score=0.857 total time=   0.0s
# [CV 1/5; 19/20] START max_leaf_nodes=10.........................................
# [CV 1/5; 19/20] END ..........max_leaf_nodes=10;, score=0.841 total time=   0.0s
# [CV 2/5; 19/20] START max_leaf_nodes=10.........................................
# [CV 2/5; 19/20] END ..........max_leaf_nodes=10;, score=0.889 total time=   0.0s
# [CV 3/5; 19/20] START max_leaf_nodes=10.........................................
# [CV 3/5; 19/20] END ..........max_leaf_nodes=10;, score=0.881 total time=   0.0s
# [CV 4/5; 19/20] START max_leaf_nodes=10.........................................
# [CV 4/5; 19/20] END ..........max_leaf_nodes=10;, score=0.833 total time=   0.0s
# [CV 5/5; 19/20] START max_leaf_nodes=10.........................................
# [CV 5/5; 19/20] END ..........max_leaf_nodes=10;, score=0.881 total time=   0.0s
# [CV 1/5; 20/20] START max_leaf_nodes=56.........................................
# [CV 1/5; 20/20] END ..........max_leaf_nodes=56;, score=0.825 total time=   0.0s
# [CV 2/5; 20/20] START max_leaf_nodes=56.........................................
# [CV 2/5; 20/20] END ..........max_leaf_nodes=56;, score=0.873 total time=   0.0s
# [CV 3/5; 20/20] START max_leaf_nodes=56.........................................
# [CV 3/5; 20/20] END ..........max_leaf_nodes=56;, score=0.833 total time=   0.0s
# [CV 4/5; 20/20] START max_leaf_nodes=56.........................................
# [CV 4/5; 20/20] END ..........max_leaf_nodes=56;, score=0.817 total time=   0.0s
# [CV 5/5; 20/20] START max_leaf_nodes=56.........................................
# [CV 5/5; 20/20] END ..........max_leaf_nodes=56;, score=0.865 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid=[{'criterion': ['gini', 'entropy']},
#                          {'max_depth': [10, 15, 2, 33, 5, None]},
#                          {'min_samples_leaf': [1, 5, 4, 3, 2]},
#                          {'max_leaf_nodes': [None, 3, 50, 100, 23, 10, 56]}],
#              verbose=10)

# %%
print('Decision Tree Classifier')
# Paramètres optimaux
print('Paramètres optimaux',dtc_best_model.best_params_)
# Modele optimal
print('Modèle optimal',dtc_best_model.best_estimator_)
# Meilleur score
print('Meilleur score',dtc_best_model.best_score_)
# Out:
# Decision Tree Classifier
# Paramètres optimaux {'max_depth': 2}
# Modèle optimal DecisionTreeClassifier(max_depth=2)
# Meilleur score 0.8714285714285716

# %% [markdown]
# ## Naive Bayesian

# %%
# Instanciation du modèle
model_gnb = GaussianNB()
# Fitting du modéle
model_gnb.fit(X_train, Y_train)
# Prédiction du modéle
pred_gnb = model_gnb.predict(X_test)

# %%
#parametre du grid
params=[
    {'priors':[None]},
    {'var_smoothing':[1.5,2,3.7]}
]
gnb_best_model = GridSearchCV(model_gnb,params,cv=5,verbose=10)
gnb_best_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START priors=None.................................................
# [CV 1/5; 1/4] END ..................priors=None;, score=0.841 total time=   0.0s
# [CV 2/5; 1/4] START priors=None.................................................
# [CV 2/5; 1/4] END ..................priors=None;, score=0.865 total time=   0.0s
# [CV 3/5; 1/4] START priors=None.................................................
# [CV 3/5; 1/4] END ..................priors=None;, score=0.841 total time=   0.0s
# [CV 4/5; 1/4] START priors=None.................................................
# [CV 4/5; 1/4] END ..................priors=None;, score=0.825 total time=   0.0s
# [CV 5/5; 1/4] START priors=None.................................................
# [CV 5/5; 1/4] END ..................priors=None;, score=0.833 total time=   0.0s
# [CV 1/5; 2/4] START var_smoothing=1.5...........................................
# [CV 1/5; 2/4] END ............var_smoothing=1.5;, score=0.810 total time=   0.0s
# [CV 2/5; 2/4] START var_smoothing=1.5...........................................
# [CV 2/5; 2/4] END ............var_smoothing=1.5;, score=0.786 total time=   0.0s
# [CV 3/5; 2/4] START var_smoothing=1.5...........................................
# [CV 3/5; 2/4] END ............var_smoothing=1.5;, score=0.762 total time=   0.0s
# [CV 4/5; 2/4] START var_smoothing=1.5...........................................
# [CV 4/5; 2/4] END ............var_smoothing=1.5;, score=0.754 total time=   0.0s
# [CV 5/5; 2/4] START var_smoothing=1.5...........................................
# [CV 5/5; 2/4] END ............var_smoothing=1.5;, score=0.762 total time=   0.0s
# [CV 1/5; 3/4] START var_smoothing=2.............................................
# [CV 1/5; 3/4] END ..............var_smoothing=2;, score=0.810 total time=   0.0s
# [CV 2/5; 3/4] START var_smoothing=2.............................................
# [CV 2/5; 3/4] END ..............var_smoothing=2;, score=0.786 total time=   0.0s
# [CV 3/5; 3/4] START var_smoothing=2.............................................
# [CV 3/5; 3/4] END ..............var_smoothing=2;, score=0.754 total time=   0.0s
# [CV 4/5; 3/4] START var_smoothing=2.............................................
# [CV 4/5; 3/4] END ..............var_smoothing=2;, score=0.754 total time=   0.0s
# [CV 5/5; 3/4] START var_smoothing=2.............................................
# [CV 5/5; 3/4] END ..............var_smoothing=2;, score=0.770 total time=   0.0s
# [CV 1/5; 4/4] START var_smoothing=3.7...........................................
# [CV 1/5; 4/4] END ............var_smoothing=3.7;, score=0.817 total time=   0.0s
# [CV 2/5; 4/4] START var_smoothing=3.7...........................................
# [CV 2/5; 4/4] END ............var_smoothing=3.7;, score=0.786 total time=   0.0s
# [CV 3/5; 4/4] START var_smoothing=3.7...........................................
# [CV 3/5; 4/4] END ............var_smoothing=3.7;, score=0.746 total time=   0.0s
# [CV 4/5; 4/4] START var_smoothing=3.7...........................................
# [CV 4/5; 4/4] END ............var_smoothing=3.7;, score=0.738 total time=   0.0s
# [CV 5/5; 4/4] START var_smoothing=3.7...........................................
# [CV 5/5; 4/4] END ............var_smoothing=3.7;, score=0.754 total time=   0.0s
# GridSearchCV(cv=5, estimator=GaussianNB(),
#              param_grid=[{'priors': [None]}, {'var_smoothing': [1.5, 2, 3.7]}],
#              verbose=10)

# %%
print('Naive Bayesian')
# Paramètres optimaux
print('Paramètres optimaux',gnb_best_model.best_params_)
# Modele optimal
print('Modèle optimal',gnb_best_model.best_estimator_)
# Meilleur score
print('Meilleur score',gnb_best_model.best_score_)
# Out:
# Naive Bayesian
# Paramètres optimaux {'priors': None}
# Modèle optimal GaussianNB()
# Meilleur score 0.8412698412698413

# %%
# 1- Nearest Centroid
# Instanciaion du modèle 
model_ncc = NearestCentroid(metric='manhattan')
# Fitting du modèle
model_ncc.fit(X_train,Y_train)
# Prédiction
pred_ncc = model_ncc.predict(X_test)
# Calculons l'accuracy
ncc_score = accuracy_score(Y_test, pred_ncc)
print('le score est du model_ncc :',(ncc_score*100),'%')
# Out:
# le score est du model_ncc : 79.25925925925927 %

# %%
# 2- K-Nearest Neighbors
# Instanciaion du modèle 
model_knn = KNeighborsClassifier(n_neighbors=7)
# Fitting du modèle
model_knn.fit(X_train,Y_train)
# Prédiction
pred_knn = model_knn.predict(X_test)
# Calculons l'accuracy
knn_score = accuracy_score(Y_test, pred_knn)
print('le score est du model_knn :',(knn_score*100),'%')
# Out:
# le score est du model_knn : 80.74074074074075 %

# %%
# 3- Régression Logistique
# Instanciaion du modèle 
model_lr = LogisticRegression(solver='newton-cg')
# Fitting du modèle
model_lr.fit(X_train,Y_train)
# Prédiction
pred_lr = model_lr.predict(X_test)
# Calculons l'accuracy
score_lr = accuracy_score(Y_test,pred_lr)
print('le score est du model_lr :',(score_lr*100),'%')
# Out:
# le score est du model_lr : 83.7037037037037 %
# /Users/retina/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(

# %%
# 4- Naive Bayesian
# Instanciation du modèle
model_gnb = GaussianNB()
# Fitting du modéle
model_gnb.fit(X_train, Y_train)
# Prédiction du modéle
pred_gnb = model_gnb.predict(X_test)
# Calculons l'accuracy
gnb_score = accuracy_score(Y_test, pred_gnb)
print('le score est du model_gnb :',(gnb_score*100),'%')
# Out:
# le score est du model_gnb : 78.14814814814814 %

# %%
# 5- Arbre de décision
# Instanciation
model_dtc = DecisionTreeClassifier(max_depth=2)
# Fitting du modéle
model_dtc.fit(X_train, Y_train)
# Prédiction du modéle
pred_dtc = model_dtc.predict(X_test)
# Calculons l'accuracy
dtc_score = accuracy_score(Y_test, pred_dtc)
print('le score est du model_dtc :',(dtc_score*100),'%')
# Out:
# le score est du model_dtc : 82.96296296296296 %

# %% [markdown]
# Nous constatons que le score du model_lr est supérieur aux autres.
# Nous pouvons en concluire que le modèle Regression Logistique est plus efficace.
